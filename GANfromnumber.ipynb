# %%
import tensorflow as tf
import numpy as np
import math
import matplotlib.pyplot as plt
 
import os
import random
import sklearn
from scipy.ndimage import imread
def load_input_images(path):
    working_dir = path
    file_list = []
    for root, dirs, files in os.walk(working_dir):
        for filename in files:
            if filename.endswith('.jpg'):
                file_list.append(root + "/" + filename) 
    images = []
    for myfile in file_list:
        image = imread(myfile)
        images.append(image)
    num_images = len(images)
    images=np.asarray(images)
    
    images=images.reshape(num_images,1,28,28)
    images=images.reshape(images.shape[0], 1, 28, 28).transpose(
        0, 2, 3, 1).astype("uint8")
       
    return images / 255.0
def get_label_list(path):
    
    working_dir=os.listdir(path)
    count=0
    label_list=[]
    #label_list_new=[]
    for i in range(100):
        j=os.listdir(os.path.join(path,working_dir[i]))
        for myfile in j:
            label_list.append((count))
        count=count+1
    label_list=np.asarray(label_list)
   
    return label_list
train_path = "./dataset/mnist"
labels_path='./dataset/mnist'
train_images=load_input_images(train_path)
train_labels=get_label_list(labels_path)
print train_images.shape, train_labels.shape
# Out:
# (60000, 28, 28, 1) (60000,)

# %%
def viz_grid(Xs, padding):
    N, H, W, C = Xs.shape
    grid_size = int(math.ceil(math.sqrt(N)))
    grid_height = H * grid_size + padding * (grid_size + 1)
    grid_width = W * grid_size + padding * (grid_size + 1)
    grid = np.zeros((grid_height, grid_width, C))
    next_idx = 0
    y0, y1 = padding, H + padding
    for y in range(grid_size):
        x0, x1 = padding, W + padding
        for x in range(grid_size):
            if next_idx < N:
                img = Xs[next_idx]
                grid[y0:y1, x0:x1] = img
                next_idx += 1
            x0 += W + padding
            x1 += W + padding
        y0 += H + padding
        y1 += H + padding
    return grid

def max_pool(input, kernel_size, stride):
    ksize = [1, kernel_size, kernel_size, 1]
    strides = [1, stride, stride, 1]
    return tf.nn.max_pool(input, ksize=ksize, strides=strides, padding='SAME')

def conv2d(input, kernel_size, stride, num_filter, name = 'conv2d'):
    with tf.variable_scope(name):
        stride_shape = [1, stride, stride, 1]
        filter_shape = [kernel_size, kernel_size, input.get_shape()[3], num_filter]

        W = tf.get_variable('w', filter_shape, tf.float32, tf.random_normal_initializer(0.0, 0.02))
        b = tf.get_variable('b', [1, 1, 1, num_filter], initializer = tf.constant_initializer(0.0))
        return tf.nn.conv2d(input, W, stride_shape, padding = 'SAME') + b

def conv2d_transpose(input, kernel_size, stride, num_filter, name = 'conv2d_transpose'):
    with tf.variable_scope(name):
        stride_shape = [1, stride, stride, 1]
        filter_shape = [kernel_size, kernel_size, num_filter, input.get_shape()[3]]
        output_shape = tf.stack([tf.shape(input)[0], tf.shape(input)[1] * 2, tf.shape(input)[2] * 2, num_filter])

        W = tf.get_variable('w', filter_shape, tf.float32, tf.random_normal_initializer(0.0, 0.02))
        b = tf.get_variable('b', [1, 1, 1, num_filter], initializer = tf.constant_initializer(0.0))
        return tf.nn.conv2d_transpose(input, W, output_shape, stride_shape, padding = 'SAME') + b

def fc(input, num_output, name = 'fc'):
    with tf.variable_scope(name):
        num_input = input.get_shape()[1]
        W = tf.get_variable('w', [num_input, num_output], tf.float32, tf.random_normal_initializer(0.0, 0.02))
        b = tf.get_variable('b', [num_output], initializer = tf.constant_initializer(0.0))
        return tf.matmul(input, W) + b

def batch_norm(input, is_training):
    out = tf.contrib.layers.batch_norm(input, decay = 0.99, center = True, scale = True,
                                       is_training = is_training, updates_collections = None)
    return out

def leaky_relu(input, alpha = 0.2):
    return tf.maximum(alpha * input, input)


class DCGAN(object):

    def __init__(self):
        self.num_epoch = 10
        self.batch_size = 64
        self.log_step = 50
        self.visualize_step = 200
        self.code_size = 256
        self.learning_rate = 1e-4
        self.vis_learning_rate = 1e-2
        self.recon_steps = 200
        self.actmax_steps = 100
        
        self._dis_called = False
        self._gen_called = False

        self.tracked_noise = np.random.normal(0, 1, [64, self.code_size])

        self.real_input = tf.placeholder(tf.float32, [None, 28, 28, 1])
        self.real_label = tf.placeholder(tf.float32, [None, 1])
        self.fake_label = tf.placeholder(tf.float32, [None, 1])
        self.noise = tf.placeholder(tf.float32, [None, self.code_size])
        self.one_hot=tf.placeholder(tf.float32, [None, 100])
        
        self.is_train = tf.placeholder(tf.bool)
        
        #self.recon_sample = tf.placeholder(tf.float32, [1, 32, 32, 3])
        #self.actmax_label = tf.placeholder(tf.float32, [1, 1])
        
        with tf.variable_scope('actmax'):
            self.actmax_code = tf.get_variable('actmax_code', [1, self.code_size],
                                               initializer = tf.constant_initializer(0.0))
        
        self._init_ops()


    def _discriminator(self, input):
        # We have multiple instances of the discriminator in the same computation graph,
        # so set variable sharing if this is not the first invocation of this function.
        with tf.variable_scope('dis', reuse = self._dis_called):
            self._dis_called = True
            
            dis_conv1 = conv2d(input, 7, 1, 32, 'conv1')
            dis_lrelu1 = leaky_relu(dis_conv1)
            dis_maxpool1 = max_pool(dis_lrelu1,3,2 )
            
            dis_conv2 = conv2d(dis_maxpool1, 5, 1, 64, 'conv2')
            dis_batchnorm2 = batch_norm(dis_conv2, self.is_train)
            dis_lrelu2 = leaky_relu(dis_batchnorm2)
            dis_maxpool2 = max_pool(dis_lrelu2,3,2)     
            
            dis_conv3 = conv2d(dis_maxpool2, 5, 1, 32, 'conv3')
            dis_batchnorm3 = batch_norm(dis_conv3, self.is_train)
            dis_lrelu3 = leaky_relu(dis_batchnorm3)
            dis_mazpool3 = max_pool(dis_lrelu3,3,2) 
            
            dis_reshape3 = tf.reshape(dis_mazpool3, [-1, 4 * 4 * 32])
            dis_fc4 = fc(dis_reshape3, 256, 'fc4')
            dis_lrelu3 = leaky_relu(dis_fc4)
            dis_fc5 = fc(dis_lrelu3, 1, 'fc5')
            
            return dis_fc5

    def _generator(self, noise,one_hot_number):
        with tf.variable_scope('gen', reuse = self._gen_called):
            self._gen_called = True
            gen_fc1 = fc(one_hot_number, 256, 'fc1')
            gen_l2_norm = tf.nn.l2_normalize(gen_fc1,0)
            z_text = tf.concat([noise, gen_l2_norm], 1)
            
            gen_fc2 = fc(z_text, 784*2, 'fc2')
            gen_relu2 = leaky_relu(gen_fc2)
            
            gen_reshape1 = tf.reshape(gen_relu2, [-1, 28, 28, 2])
            print gen_reshape1.shape
            
            
            gen_batchnorm1 = batch_norm(gen_reshape1, self.is_train)
            gen_lrelu1 = leaky_relu(gen_batchnorm1)
            print gen_lrelu1.shape
            gen_conv2 = conv2d(gen_lrelu1, 4, 1, 64, 'conv2')
            gen_batchnorm2 = batch_norm(gen_conv2, self.is_train)
            gen_lrelu2 = leaky_relu(gen_batchnorm2)
            print(gen_lrelu2.shape)
            gen_conv3 = conv2d(gen_lrelu2, 4, 1, 32, 'conv3')
            gen_batchnorm3 = batch_norm(gen_conv3, self.is_train)
            gen_lrelu3 = leaky_relu(gen_batchnorm3)
            gen_conv4 = conv2d(gen_lrelu3, 4, 1, 1, 'conv4')
            
            gen_sigmoid4 = tf.sigmoid(gen_conv4)
            print(gen_sigmoid4.shape)
            return gen_sigmoid4

    def _loss(self, labels, logits):
        loss = tf.nn.sigmoid_cross_entropy_with_logits(labels = labels, logits = logits)
        return tf.reduce_mean(loss)

    def _reconstruction_loss(self, generated, target):
        loss = tf.nn.l2_loss(generated - target)
        return tf.reduce_mean(loss)
    
    # Define operations
    def _init_ops(self):
        
        ################################################################################
        # Prob 2-1: complete the definition of these operations                        #
        ################################################################################
        
        self.fake_samples_op = self._generator(self.noise, self.one_hot)
        self.dis_loss_op = self._loss(self.real_label, self._discriminator(self.real_input)) +self._loss(self.fake_label,self._discriminator(self.fake_samples_op))
        self.gen_loss_op = self._loss(self.real_label,self._discriminator(self.fake_samples_op))
        
        
        dis_optimizer = tf.train.RMSPropOptimizer(self.learning_rate)
        first_train_vars = tf.get_collection(tf.GraphKeys.TRAINABLE_VARIABLES,
                                     "dis")
        self.dis_train_op = dis_optimizer.minimize(self.dis_loss_op,var_list = first_train_vars)
        
        gen_optimizer = tf.train.RMSPropOptimizer(self.learning_rate)
        second_train_vars = tf.get_collection(tf.GraphKeys.TRAINABLE_VARIABLES,
                                     "gen")
        self.gen_train_op = gen_optimizer.minimize(self.gen_loss_op, var_list = second_train_vars)

    # Training function
    def train(self, sess,train_images ):
        sess.run(tf.global_variables_initializer())

        num_train = train_images.shape[0]
        step = 0
        
        # smooth the loss curve so that it does not fluctuate too much
        smooth_factor = 0.95
        plot_dis_s = 0
        plot_gen_s = 0
        plot_ws = 0
        
        dis_losses = []
        gen_losses = []
        for epoch in range(self.num_epoch):
            for i in range(num_train // (self.batch_size)):
                step += 1
                
                image_batch = train_images[i * self.batch_size : (i + 1) * self.batch_size]
                labels=train_labels[i * self.batch_size : (i + 1) * self.batch_size]
                noise = np.random.normal(0, 1, [self.batch_size, 256])
                one_hot_vec = np.zeros([self.batch_size, 100])
                #one_hot=np.zeros([self.batch_size, 100])
                zeros = np.zeros([self.batch_size, 1])
                ones = np.ones([self.batch_size, 1])
                for j in range(self.batch_size ):
                    #if (j == 31):
                        #print(i*self.batch_size + j)
                    one_hot_vec[j][labels[j]] = 1

               
                
                dis_feed_dict = {self.real_input:image_batch, self.real_label:ones, self.fake_label:zeros,self.noise:noise,self.is_train:True, self.one_hot:one_hot_vec}
        
              

                _, dis_loss = sess.run([self.dis_train_op, self.dis_loss_op], feed_dict = dis_feed_dict)
        
               
                
                gen_feed_dict = {self.noise:noise,self.one_hot:one_hot_vec,self.real_label:ones,self.is_train:True}
        
               
                _, gen_loss = sess.run([self.gen_train_op, self.gen_loss_op], feed_dict = gen_feed_dict)

                plot_dis_s = plot_dis_s * smooth_factor + dis_loss * (1 - smooth_factor)
                plot_gen_s = plot_gen_s * smooth_factor + gen_loss * (1 - smooth_factor)
                plot_ws = plot_ws * smooth_factor + (1 - smooth_factor)
                dis_losses.append(plot_dis_s / plot_ws)
                gen_losses.append(plot_gen_s / plot_ws)

                if step % self.log_step == 0:
                    print('Iteration {0}: dis loss = {1:.4f}, gen loss = {2:.4f}'.format(step, dis_loss, gen_loss))

            #fig = plt.figure(figsize = (8, 8))   
            #ax1 = plt.subplot(111)
            #generated_image = self.generate(self.tracked_noise)
            #print(generated_image.shape)
            #image = viz_grid(generated_image, 1)
            #print(image.shape)
            #image = image.reshape(30,30)
            #list = []
            #for i in range(3):
                #for j in range(image.shape[0]):
                    #list.append(image[j])
            #image = np.array(list)
            #image = image.reshape(30,30,3)
            
            fig = plt.figure(figsize = (8, 8))   
            ax1 = plt.subplot(111)
            gen = self.generate(self.tracked_noise)
            print (gen.shape)
            images = viz_grid(gen, 1)
            images = images.reshape(233,233)
            ax1.imshow(images,cmap='gray')
            plt.show()

            plt.plot(dis_losses)
            plt.title('discriminator loss')
            plt.xlabel('iterations')
            plt.ylabel('loss')
            plt.show()

            plt.plot(gen_losses)
            plt.title('generator loss')
            plt.xlabel('iterations')
            plt.ylabel('loss')
            plt.show()


    # Generates a single sample from input code
    def generate_one_sample(self, code, i):
        #print train_labels[i]
        #print code
        one_hot_vec=np.zeros([1,100])
        one_hot_vec[0][i]=1
        
        gen_vis_feed_dict = {self.noise:code,self.one_hot:one_hot_vec,self.is_train:True}
        
        generated = sess.run(self.fake_samples_op, feed_dict = gen_vis_feed_dict)
        return generated

    # Generates samples from input batch of codes
    def generate(self, codes):
        generated = np.zeros((codes.shape[0], 28, 28, 1))
        for i in range(codes.shape[0]):
            generated[i:i+1] = self.generate_one_sample(codes[i:i+1],i)
        return generated



    # Perform activation maximization on a batch of different initial codes
    def actmax(self, initial_codes):
        actmax_results = np.zeros((initial_codes.shape[0], 32, 32, 3))
        for i in range(initial_codes.shape[0]):
            actmax_results[i:i+1] = self.actmax_one_sample(initial_codes[i:i+1])
        return actmax_results.clip(0, 1)
    
tf.reset_default_graph()

with tf.Session() as sess:
    with tf.device('/cpu:0'):
        dcgan = DCGAN()
        sess.run(tf.global_variables_initializer())
        train_images = np.array(train_images)
        
        dcgan.train(sess, train_images)
        dis_var_list = tf.get_collection(tf.GraphKeys.GLOBAL_VARIABLES, 'dis')
        gen_var_list = tf.get_collection(tf.GraphKeys.GLOBAL_VARIABLES, 'gen')
        saver = tf.train.Saver(dis_var_list + gen_var_list)
        saver.save(sess, 'model/dcgan')
# Out:
# (?, 28, 28, 2)
# (?, 28, 28, 2)
# (?, 28, 28, 64)
# (?, 28, 28, 1)
# Iteration 50: dis loss = 1.0727, gen loss = 0.9410
# Iteration 100: dis loss = 0.1747, gen loss = 2.4951
# Iteration 150: dis loss = 0.0233, gen loss = 4.8196
# Iteration 200: dis loss = 0.0038, gen loss = 7.2107
# Iteration 250: dis loss = 0.0547, gen loss = 5.0572
# Iteration 300: dis loss = 0.2797, gen loss = 1.2967
# Iteration 350: dis loss = 0.4577, gen loss = 1.4772
# Iteration 400: dis loss = 0.4862, gen loss = 2.3508
# Iteration 450: dis loss = 0.4345, gen loss = 2.0690
# Iteration 500: dis loss = 0.9287, gen loss = 0.4688
# Iteration 550: dis loss = 0.4056, gen loss = 4.0161
# Iteration 600: dis loss = 0.2073, gen loss = 3.4872
# Iteration 650: dis loss = 0.2457, gen loss = 2.8068
# Iteration 700: dis loss = 0.1346, gen loss = 3.4349
# Iteration 750: dis loss = 0.2959, gen loss = 2.4593
# Iteration 800: dis loss = 0.1907, gen loss = 3.8499
# Iteration 850: dis loss = 0.2935, gen loss = 3.1068
# Iteration 900: dis loss = 0.7275, gen loss = 0.4424
# (64, 28, 28, 1)
# Iteration 950: dis loss = 0.0998, gen loss = 4.0666
# Iteration 1000: dis loss = 0.1032, gen loss = 4.9730
# Iteration 1050: dis loss = 0.9022, gen loss = 0.6902
# Iteration 1100: dis loss = 0.1256, gen loss = 3.9397
# Iteration 1150: dis loss = 0.1072, gen loss = 4.7578
# Iteration 1200: dis loss = 0.2314, gen loss = 3.7469
# Iteration 1250: dis loss = 0.0820, gen loss = 4.3367
# Iteration 1300: dis loss = 0.2612, gen loss = 2.8213
# Iteration 1350: dis loss = 0.1601, gen loss = 4.6280
# Iteration 1400: dis loss = 0.3550, gen loss = 3.9841
# Iteration 1450: dis loss = 0.4987, gen loss = 1.5012
# Iteration 1500: dis loss = 0.2672, gen loss = 2.7273
# Iteration 1550: dis loss = 0.2183, gen loss = 2.2957
# Iteration 1600: dis loss = 0.3032, gen loss = 7.3450
# Iteration 1650: dis loss = 0.0330, gen loss = 5.3336
# Iteration 1700: dis loss = 0.9874, gen loss = 5.1650
# Iteration 1750: dis loss = 0.0795, gen loss = 4.2690
# Iteration 1800: dis loss = 0.0961, gen loss = 4.0401
# Iteration 1850: dis loss = 0.9428, gen loss = 5.7467
# (64, 28, 28, 1)
# Iteration 1900: dis loss = 0.0316, gen loss = 5.0430
# Iteration 1950: dis loss = 0.0538, gen loss = 5.9044
# Iteration 2000: dis loss = 0.1189, gen loss = 3.8505
# Iteration 2050: dis loss = 1.8117, gen loss = 6.3412
# Iteration 2100: dis loss = 2.2039, gen loss = 0.3027
# Iteration 2150: dis loss = 1.4758, gen loss = 6.0884
# Iteration 2200: dis loss = 0.0295, gen loss = 5.4502
# Iteration 2250: dis loss = 4.1355, gen loss = 3.6511
# Iteration 2300: dis loss = 0.0606, gen loss = 4.6848
# Iteration 2350: dis loss = 0.1139, gen loss = 3.8445
# Iteration 2400: dis loss = 0.2813, gen loss = 3.9193
# Iteration 2450: dis loss = 0.1586, gen loss = 6.9580
# Iteration 2500: dis loss = 0.0289, gen loss = 5.4793
# Iteration 2550: dis loss = 0.0558, gen loss = 4.7220
# Iteration 2600: dis loss = 3.7501, gen loss = 1.0927
# Iteration 2650: dis loss = 0.1936, gen loss = 4.6329
# Iteration 2700: dis loss = 0.0457, gen loss = 5.0723
# Iteration 2750: dis loss = 0.1839, gen loss = 5.8142
# Iteration 2800: dis loss = 0.1268, gen loss = 3.7269
# (64, 28, 28, 1)
# Iteration 2850: dis loss = 0.0412, gen loss = 4.8378
# Iteration 2900: dis loss = 0.0288, gen loss = 6.3487
# Iteration 2950: dis loss = 0.0638, gen loss = 4.9252
# Iteration 3000: dis loss = 0.0935, gen loss = 4.9832
# Iteration 3050: dis loss = 0.0158, gen loss = 6.6718
# Iteration 3100: dis loss = 0.0471, gen loss = 4.9907
# Iteration 3150: dis loss = 0.0200, gen loss = 5.5707
# Iteration 3200: dis loss = 0.2682, gen loss = 3.3728
# Iteration 3250: dis loss = 0.0217, gen loss = 6.3003
# Iteration 3300: dis loss = 2.1582, gen loss = 9.5515
# Iteration 3350: dis loss = 0.0286, gen loss = 5.1465
# Iteration 3400: dis loss = 0.8345, gen loss = 12.3385
# Iteration 3450: dis loss = 0.9928, gen loss = 9.3332
# Iteration 3500: dis loss = 0.0356, gen loss = 5.0031
# Iteration 3550: dis loss = 0.0208, gen loss = 5.7033
# Iteration 3600: dis loss = 2.1813, gen loss = 2.4170
# Iteration 3650: dis loss = 0.0181, gen loss = 5.8514
# Iteration 3700: dis loss = 0.3267, gen loss = 6.1903
# (64, 28, 28, 1)
# Iteration 3750: dis loss = 0.0268, gen loss = 5.5806
# Iteration 3800: dis loss = 0.0336, gen loss = 5.1486
# Iteration 3850: dis loss = 0.0400, gen loss = 5.2711
# Iteration 3900: dis loss = 0.2259, gen loss = 10.7098
# Iteration 3950: dis loss = 0.1005, gen loss = 5.6223
# Iteration 4000: dis loss = 0.0292, gen loss = 5.7456
# Iteration 4050: dis loss = 2.5753, gen loss = 11.0896
# Iteration 4100: dis loss = 0.0256, gen loss = 5.9144
# Iteration 4150: dis loss = 0.0264, gen loss = 5.6439
# Iteration 4200: dis loss = 1.0532, gen loss = 11.5241
# Iteration 4250: dis loss = 0.0325, gen loss = 5.4497
# Iteration 4300: dis loss = 0.0182, gen loss = 7.7196
# Iteration 4350: dis loss = 0.0120, gen loss = 6.9718
# Iteration 4400: dis loss = 0.0082, gen loss = 6.3014
# Iteration 4450: dis loss = 0.0266, gen loss = 5.9570
# Iteration 4500: dis loss = 0.0163, gen loss = 6.5746
# Iteration 4550: dis loss = 0.0695, gen loss = 5.2366
# Iteration 4600: dis loss = 0.0380, gen loss = 5.2062
# Iteration 4650: dis loss = 0.0208, gen loss = 5.7618
# (64, 28, 28, 1)
# Iteration 4700: dis loss = 0.0134, gen loss = 6.3027
# Iteration 4750: dis loss = 0.0215, gen loss = 5.3671
# Iteration 4800: dis loss = 0.6746, gen loss = 6.9596
# Iteration 4850: dis loss = 0.1808, gen loss = 8.6518
# Iteration 4900: dis loss = 0.0503, gen loss = 5.7868
# Iteration 4950: dis loss = 0.2678, gen loss = 5.5203
# Iteration 5000: dis loss = 0.0754, gen loss = 5.0248
# Iteration 5050: dis loss = 0.0552, gen loss = 4.7521
# Iteration 5100: dis loss = 0.0985, gen loss = 5.8420
# Iteration 5150: dis loss = 0.0845, gen loss = 4.3039
# Iteration 5200: dis loss = 0.0482, gen loss = 5.5661
# Iteration 5250: dis loss = 0.1525, gen loss = 5.0866
# Iteration 5300: dis loss = 0.1937, gen loss = 4.8454
# Iteration 5350: dis loss = 0.0554, gen loss = 4.9446
# Iteration 5400: dis loss = 0.3094, gen loss = 2.0412
# Iteration 5450: dis loss = 0.0974, gen loss = 5.3111
# Iteration 5500: dis loss = 0.0513, gen loss = 5.0548
# Iteration 5550: dis loss = 0.0646, gen loss = 3.4677
# Iteration 5600: dis loss = 0.0500, gen loss = 6.2607
# (64, 28, 28, 1)
# Iteration 5650: dis loss = 0.0045, gen loss = 7.6552
# Iteration 5700: dis loss = 0.0086, gen loss = 7.0084
# Iteration 5750: dis loss = 0.0157, gen loss = 6.0901
# Iteration 5800: dis loss = 0.0588, gen loss = 5.0156
# Iteration 5850: dis loss = 0.0192, gen loss = 8.3434
# Iteration 5900: dis loss = 0.0561, gen loss = 4.9906
# Iteration 5950: dis loss = 0.0257, gen loss = 5.9690
# Iteration 6000: dis loss = 2.4511, gen loss = 0.8821
# Iteration 6050: dis loss = 0.0162, gen loss = 6.1651
# Iteration 6100: dis loss = 0.0251, gen loss = 5.7595
# Iteration 6150: dis loss = 0.0088, gen loss = 7.1505
# Iteration 6200: dis loss = 0.0266, gen loss = 5.9459
# Iteration 6250: dis loss = 0.0688, gen loss = 4.7652
# Iteration 6300: dis loss = 0.7205, gen loss = 4.9043
# Iteration 6350: dis loss = 0.0614, gen loss = 4.8517
# Iteration 6400: dis loss = 0.0868, gen loss = 4.5696
# Iteration 6450: dis loss = 0.1943, gen loss = 3.0580
# Iteration 6500: dis loss = 0.0416, gen loss = 5.2239
# Iteration 6550: dis loss = 0.1230, gen loss = 3.4657
# (64, 28, 28, 1)
# Iteration 6600: dis loss = 0.0038, gen loss = 8.1531
# Iteration 6650: dis loss = 0.0196, gen loss = 6.5751
# Iteration 6700: dis loss = 0.0980, gen loss = 3.3472
# Iteration 6750: dis loss = 0.3436, gen loss = 5.7230
# Iteration 6800: dis loss = 0.0181, gen loss = 7.5667
# Iteration 6850: dis loss = 0.5318, gen loss = 0.0585
# Iteration 6900: dis loss = 0.0044, gen loss = 7.2242
# Iteration 6950: dis loss = 0.0374, gen loss = 6.7270
# Iteration 7000: dis loss = 0.1640, gen loss = 6.6828
# Iteration 7050: dis loss = 0.0557, gen loss = 6.0968
# Iteration 7100: dis loss = 0.1725, gen loss = 1.6250
# Iteration 7150: dis loss = 0.0438, gen loss = 6.1937
# Iteration 7200: dis loss = 0.0212, gen loss = 6.8592
# Iteration 7250: dis loss = 0.0602, gen loss = 5.3212
# Iteration 7300: dis loss = 0.1872, gen loss = 6.1362
# Iteration 7350: dis loss = 0.8780, gen loss = 11.3199
# Iteration 7400: dis loss = 0.0158, gen loss = 5.8284
# Iteration 7450: dis loss = 0.1220, gen loss = 4.3558
# (64, 28, 28, 1)
# Iteration 7500: dis loss = 0.0219, gen loss = 6.5043
# Iteration 7550: dis loss = 0.0051, gen loss = 7.6511
# Iteration 7600: dis loss = 0.0836, gen loss = 4.4861
# Iteration 7650: dis loss = 0.2372, gen loss = 5.3198
# Iteration 7700: dis loss = 0.1446, gen loss = 7.7590
# Iteration 7750: dis loss = 0.0917, gen loss = 8.4005
# Iteration 7800: dis loss = 0.1552, gen loss = 4.8853
# Iteration 7850: dis loss = 0.0348, gen loss = 5.9800
# Iteration 7900: dis loss = 0.2775, gen loss = 3.1203
# Iteration 7950: dis loss = 0.0319, gen loss = 5.7402
# Iteration 8000: dis loss = 0.0423, gen loss = 5.1886
# Iteration 8050: dis loss = 0.1100, gen loss = 3.5140
# Iteration 8100: dis loss = 0.0742, gen loss = 6.2460
# Iteration 8150: dis loss = 0.0058, gen loss = 6.6452
# Iteration 8200: dis loss = 2.9761, gen loss = 0.4719
# Iteration 8250: dis loss = 0.0403, gen loss = 5.5443
# Iteration 8300: dis loss = 0.0302, gen loss = 5.9099
# Iteration 8350: dis loss = 0.0515, gen loss = 7.3481
# Iteration 8400: dis loss = 0.0172, gen loss = 7.8575
# (64, 28, 28, 1)
# Iteration 8450: dis loss = 0.0177, gen loss = 6.5182
# Iteration 8500: dis loss = 0.0667, gen loss = 5.2190
# Iteration 8550: dis loss = 0.0167, gen loss = 6.4542
# Iteration 8600: dis loss = 0.0544, gen loss = 5.1234
# Iteration 8650: dis loss = 0.0312, gen loss = 6.0612
# Iteration 8700: dis loss = 0.2988, gen loss = 4.3256
# Iteration 8750: dis loss = 0.1313, gen loss = 4.1175
# Iteration 8800: dis loss = 0.1920, gen loss = 3.5008
# Iteration 8850: dis loss = 1.4124, gen loss = 1.0543
# Iteration 8900: dis loss = 0.0540, gen loss = 4.7900
# Iteration 8950: dis loss = 0.3211, gen loss = 5.9987
# Iteration 9000: dis loss = 0.5995, gen loss = 9.5074
# Iteration 9050: dis loss = 0.1433, gen loss = 4.6242
# Iteration 9100: dis loss = 0.3418, gen loss = 1.4414
# Iteration 9150: dis loss = 0.0585, gen loss = 4.8153
# Iteration 9200: dis loss = 0.0298, gen loss = 6.2786
# Iteration 9250: dis loss = 0.6110, gen loss = 8.6932
# Iteration 9300: dis loss = 0.1652, gen loss = 8.3930
# Iteration 9350: dis loss = 0.0425, gen loss = 5.4350
# (64, 28, 28, 1)
